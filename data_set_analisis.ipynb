# %%
import pandas as pd

col_names = ['Time', 'Source', 'Destination', 'Protocol', 'Length', 'Info','src_port','dst_port']
data_frame = pd.read_csv("smallTraffic-_backup.csv",encoding = "ISO-8859-1", header=0, names=col_names)

data_frame
# Out:
#              Time         Source      Destination     Protocol  Length  \
# 1        0.000000  192.168.3.131    72.14.213.138         HTTP     997
# 2        0.029841  72.14.213.138    192.168.3.131         HTTP     440
# 3        0.223883  192.168.3.131    72.14.213.102          TCP      66
# 4        0.229423  192.168.3.131    72.14.213.138          TCP      54
# 5        0.242649  72.14.213.102    192.168.3.131          TCP      66
# ...           ...            ...              ...          ...     ...
# 14257  298.284563      10.0.2.15     65.54.167.27          TCP      54
# 14258  298.303019  192.168.3.131  255.255.255.255  DB-LSP-DISC     162
# 14259  298.305344  192.168.3.131    192.168.3.255  DB-LSP-DISC     162
# 14260  298.503019  192.168.3.131  255.255.255.255  DB-LSP-DISC     162
# 14261  298.505344  192.168.3.131    192.168.3.255  DB-LSP-DISC     162
#
#                                                     Info  src_port  dst_port
# 1      GET /complete/search?client=chrome&hl=en-US&q=...   57011.0      80.0
# 2                     HTTP/1.1 200 OK  (text/javascript)      80.0   57011.0
# 3      55950  >  80 [SYN] Seq=0 Win=8192 Len=0 MSS=14...   55950.0      80.0
# 4      57011  >  80 [ACK] Seq=944 Ack=387 Win=16192 L...   57011.0      80.0
# 5      80  >  55950 [SYN, ACK] Seq=0 Ack=1 Win=5720 L...      80.0   55950.0
# ...                                                  ...       ...       ...
# 14257  2548  >  5480 [RST, ACK] Seq=1902 Ack=42479 Wi...    2548.0    5480.0
# 14258                Dropbox LAN sync Discovery Protocol   17500.0   17500.0
# 14259                Dropbox LAN sync Discovery Protocol   17500.0   17500.0
# 14260                Dropbox LAN sync Discovery Protocol   17500.0   17500.0
# 14261                Dropbox LAN sync Discovery Protocol   17500.0   17500.0
#
# [14261 rows x 8 columns]
