# %%
import pandas as pd

col_names = ['Time', 'Source', 'Destination', 'Protocol', 'Length', 'Info','src_port','dst_port']
data_frame = pd.read_csv("Samples/bigTraffic.csv",encoding = "ISO-8859-1", header=0, names=col_names)

data_frame
# Out:
#               Time           Source      Destination Protocol  Length  \
# 1         0.000000    172.16.133.57      68.64.21.62      UDP    1168
# 2         0.000050    172.16.133.57      68.64.21.62      UDP    1168
# 3         0.000050    172.16.133.57      68.64.21.62      UDP      94
# 4         0.000322    96.43.146.176    172.16.133.82      TCP      60
# 5         0.001160    172.16.133.56      68.64.21.42      UDP     167
# ...            ...              ...              ...      ...     ...
# 791611  299.997297    172.16.133.56      68.64.21.42      UDP     167
# 791612  299.997539  208.111.161.254    172.16.133.63     HTTP    1175
# 791613  299.998402    172.16.133.63  208.111.161.254      TCP      60
# 791614  299.999122     96.43.146.22    172.16.133.66    TLSv1     348
# 791615  299.999827   172.16.133.233   172.16.128.254     ICMP      78
#
#                                                      Info  src_port  dst_port
# 1                                 53807  >  1853 Len=1126   53807.0    1853.0
# 2                                 53807  >  1853 Len=1126   53807.0    1853.0
# 3                                   53807  >  1853 Len=52   53807.0    1853.0
# 4          443  >  61228 [ACK] Seq=1 Ack=1 Win=9659 Len=0     443.0   61228.0
# 5                                  49514  >  1853 Len=125   49514.0    1853.0
# ...                                                   ...       ...       ...
# 791611                             49514  >  1853 Len=125   49514.0    1853.0
# 791612                 HTTP/1.1 200 OK  (JPEG JFIF image)      80.0   54280.0
# 791613  54280  >  80 [ACK] Seq=6679 Ack=11285 Win=6553...   54280.0      80.0
# 791614                                   Application Data     443.0   49611.0
# 791615  Echo (ping) request  id=0x1ecb, seq=5/1280, tt...       NaN       NaN
#
# [791615 rows x 8 columns]

# %%
print(data_frame.shape)
# Out:
# (791615, 8)

# %%
print(data_frame.columns)
# Out:
# Index(['Time', 'Source', 'Destination', 'Protocol', 'Length', 'Info',
#        'src_port', 'dst_port'],
#       dtype='object')

# %%
print(data_frame.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 791615 entries, 1 to 791615
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Time         791615 non-null  float64
#  1   Source       791615 non-null  object
#  2   Destination  791615 non-null  object
#  3   Protocol     791615 non-null  object
#  4   Length       791615 non-null  int64
#  5   Info         769764 non-null  object
#  6   src_port     787861 non-null  float64
#  7   dst_port     787861 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 54.4+ MB
# None

# %%
data_frame.describe()
# Out:
#                 Time         Length       src_port       dst_port
# count  791615.000000  791615.000000  787861.000000  787861.000000
# mean      143.862952     448.978082   33324.000261   24279.656603
# std        86.458786     575.745870   27349.061551   26422.821918
# min         0.000000      60.000000       7.000000       7.000000
# 25%        70.895016      60.000000     443.000000    1184.000000
# 50%       139.364193     106.000000   49951.000000    5440.000000
# 75%       217.495987     816.000000   57238.000000   53807.000000
# max       299.999827    1514.000000   65534.000000   65531.000000

# %%
data_frame.describe(include=['object', 'bool'])
# Out:
#                Source     Destination Protocol              Info
# count          791615          791615   791615            769764
# unique           1917            1765       58            476254
# top     172.16.133.57  172.16.139.250      TCP  Application Data
# freq            30563          181258   495025             72320

# %%
#Count values
data_frame['Protocol'].value_counts()
# Out:
# TCP                     495025
# UDP                     132174
# TLSv1                    71793
# HTTP                     28154
# TLSv1.1                  18790
# VNC                      12474
# ADP                       9382
# DNS                       4372
# ICMP                      4266
# SNMP                      3418
# SSHv2                     3028
# SSLv3                     1506
# DCERPC                    1385
# sFlow                     1113
# SSDP                       623
# FRSTRANS                   606
# Syslog                     599
# NBNS                       570
# SSL                        533
# DHCPv6                     361
# IGMPv3                     271
# DB-LSP-DISC                260
# SSH                        140
# HTTP/XML                   101
# SMB                         64
# DHCP                        62
# LLMNR                       58
# SSLv2                       44
# POP/IMF                     41
# WebSocket                   40
# SIP                         40
# ICMPv6                      34
# RTMP                        31
# MPEG TS                     30
# BROWSER                     27
# MDNS                        26
# ECHO                        20
# MSNMS                       19
# XMPP/XML                    17
# OCSP                        16
# SRVLOC                      15
# IGMPv2                      15
# POP                         11
# YMSG                        10
# NBSS                         8
# LANMAN                       8
# CIGI                         7
# IOXIDResolver                6
# FTP                          5
# NTP                          4
# EPM                          2
# CLDAP                        2
# RPC_BROWSER                  2
# DRSUAPI                      2
# MP4                          2
# Elasticsearch                1
# IRC                          1
# NXP 802.15.4 SNIFFER         1
# Name: Protocol, dtype: int64

# %%
#Count values and display %
protocols = data_frame['Protocol'].unique()
percent = data_frame['Protocol'].value_counts(normalize=True)


print(percent.to_frame().iloc[0])
# Out:
# Protocol    0.625336
# Name: TCP, dtype: float64

# %%
data_frame.sort_values(by='src_port', ascending=False).head(25)
# Out:
#               Time         Source     Destination Protocol  Length  \
# 352792  123.800425  172.16.133.28  172.16.139.250     HTTP     265
# 352791  123.800083  172.16.133.28  172.16.139.250      TCP      60
# 352806  123.804437  172.16.133.28  172.16.139.250      TCP      60
# 352807  123.804438  172.16.133.28  172.16.139.250      TCP      60
# 352808  123.804440  172.16.133.28  172.16.139.250      TCP      60
# 352809  123.804513  172.16.133.28  172.16.139.250      TCP      60
# 352789  123.799956  172.16.133.28  172.16.139.250      TCP      60
# 352788  123.799243  172.16.133.28  172.16.139.250      TCP      66
# 352787  123.799118  172.16.133.28  172.16.139.250      TCP      66
# 352793  123.800566  172.16.133.28  172.16.139.250      TCP     265
# 349887  122.787507  172.16.133.28  172.16.139.250     HTTP     265
# 349881  122.786210  172.16.133.28  172.16.139.250      TCP      66
# 349882  122.786274  172.16.133.28  172.16.139.250      TCP      66
# 349884  122.787084  172.16.133.28  172.16.139.250      TCP      60
# 349885  122.787086  172.16.133.28  172.16.139.250      TCP      60
# 349901  122.792422  172.16.133.28  172.16.139.250      TCP      60
# 349888  122.787580  172.16.133.28  172.16.139.250      TCP     265
# 349900  122.792420  172.16.133.28  172.16.139.250      TCP      60
# 349902  122.792423  172.16.133.28  172.16.139.250      TCP      60
# 349903  122.792470  172.16.133.28  172.16.139.250      TCP      60
# 346231  121.776170  172.16.133.28  172.16.139.250      TCP      60
# 346202  121.770878  172.16.133.28  172.16.139.250      TCP      66
# 346203  121.770937  172.16.133.28  172.16.139.250      TCP      66
# 346205  121.771802  172.16.133.28  172.16.139.250      TCP      60
# 346207  121.771856  172.16.133.28  172.16.139.250      TCP      60
#
#                                                      Info  src_port  dst_port
# 352792  GET /CSIS/CSISISAPI.dll/?request?b2bc13b2-c435...   65534.0    5440.0
# 352791  [TCP Dup ACK 352789#1] 65534  >  5440 [ACK] Se...   65534.0    5440.0
# 352806  65534  >  5440 [ACK] Seq=212 Ack=184 Win=65516...   65534.0    5440.0
# 352807  [TCP Dup ACK 352806#1] 65534  >  5440 [ACK] Se...   65534.0    5440.0
# 352808  65534  >  5440 [FIN, ACK] Seq=212 Ack=184 Win=...   65534.0    5440.0
# 352809  [TCP Out-Of-Order] 65534  >  5440 [FIN, ACK] S...   65534.0    5440.0
# 352789   65534  >  5440 [ACK] Seq=1 Ack=1 Win=65700 Len=0   65534.0    5440.0
# 352788  [TCP Out-Of-Order] 65534  >  5440 [SYN] Seq=0 ...   65534.0    5440.0
# 352787  65534  >  5440 [SYN] Seq=0 Win=8192 Len=0 MSS=...   65534.0    5440.0
# 352793  [TCP Retransmission] 65534  >  5440 [PSH, ACK]...   65534.0    5440.0
# 349887  GET /CSIS/CSISISAPI.dll/?request?b2bc13b2-c435...   65533.0    5440.0
# 349881  65533  >  5440 [SYN] Seq=0 Win=8192 Len=0 MSS=...   65533.0    5440.0
# 349882  [TCP Out-Of-Order] 65533  >  5440 [SYN] Seq=0 ...   65533.0    5440.0
# 349884   65533  >  5440 [ACK] Seq=1 Ack=1 Win=65700 Len=0   65533.0    5440.0
# 349885  [TCP Dup ACK 349884#1] 65533  >  5440 [ACK] Se...   65533.0    5440.0
# 349901  [TCP Dup ACK 349900#1] 65533  >  5440 [ACK] Se...   65533.0    5440.0
# 349888  [TCP Retransmission] 65533  >  5440 [PSH, ACK]...   65533.0    5440.0
# 349900  65533  >  5440 [ACK] Seq=212 Ack=184 Win=65516...   65533.0    5440.0
# 349902  65533  >  5440 [FIN, ACK] Seq=212 Ack=184 Win=...   65533.0    5440.0
# 349903  [TCP Out-Of-Order] 65533  >  5440 [FIN, ACK] S...   65533.0    5440.0
# 346231  65532  >  5440 [ACK] Seq=212 Ack=184 Win=65516...   65532.0    5440.0
# 346202  65532  >  5440 [SYN] Seq=0 Win=8192 Len=0 MSS=...   65532.0    5440.0
# 346203  [TCP Out-Of-Order] 65532  >  5440 [SYN] Seq=0 ...   65532.0    5440.0
# 346205   65532  >  5440 [ACK] Seq=1 Ack=1 Win=65700 Len=0   65532.0    5440.0
# 346207  [TCP Dup ACK 346205#1] 65532  >  5440 [ACK] Se...   65532.0    5440.0

# %%
arrayOfProtocols = data_frame['Protocol'].unique()
arrayOfLengths = []
arrayOfCountProtocols = []

for x in arrayOfProtocols:
    arrayOfLengths.append(data_frame.loc[data_frame['Protocol'] == x, 'Length'].mean())
    arrayOfCountProtocols.append(list(data_frame.Protocol.to_numpy()).count(x))
    
d = {
    'Protocol': arrayOfProtocols,
    'Packet length mean': arrayOfLengths,
    'Count': arrayOfCountProtocols
}

df = pd.DataFrame(data=d).round(2)

df
# Out:
#                 Protocol  Packet length mean   Count
# 0                    UDP              268.04  132174
# 1                    TCP              477.10  495025
# 2                   HTTP              476.72   28154
# 3                    ADP               77.64    9382
# 4                  TLSv1              554.71   71793
# 5                   ICMP               85.21    4266
# 6                    VNC              672.55   12474
# 7                    SSL              107.71     533
# 8                 Syslog              346.49     599
# 9                    DNS              108.00    4372
# 10                  NBNS               93.16     570
# 11                DHCPv6              158.80     361
# 12                 sFlow             1341.67    1113
# 13                   SSH              182.14     140
# 14                  SNMP              147.35    3418
# 15               TLSv1.1              844.52   18790
# 16                  DHCP              354.73      62
# 17                  SSDP              182.32     623
# 18                  RTMP              294.90      31
# 19                 SSLv3              495.48    1506
# 20                  CIGI              167.00       7
# 21              HTTP/XML              693.35     101
# 22                   SIP              717.95      40
# 23                DCERPC              376.50    1385
# 24         IOXIDResolver               92.67       6
# 25               BROWSER              244.22      27
# 26           DB-LSP-DISC              167.96     260
# 27               MPEG TS              544.67      30
# 28                  MDNS              358.85      26
# 29                 MSNMS               61.05      19
# 30                IGMPv3               63.65     271
# 31                IGMPv2               60.00      15
# 32                ICMPv6              122.82      34
# 33                 SSHv2              143.87    3028
# 34  NXP 802.15.4 SNIFFER               78.00       1
# 35                  ECHO               60.00      20
# 36                   MP4             1122.00       2
# 37              XMPP/XML              328.47      17
# 38                SRVLOC               89.20      15
# 39                 LLMNR               74.00      58
# 40         Elasticsearch              106.00       1
# 41                  YMSG              103.10      10
# 42                 SSLv2              121.20      44
# 43             WebSocket               66.20      40
# 44                   FTP               81.00       5
# 45                   IRC              265.00       1
# 46                  OCSP              711.06      16
# 47                 CLDAP              205.00       2
# 48                   NTP               90.00       4
# 49                  NBSS               93.00       8
# 50                   SMB              211.36      64
# 51                LANMAN              393.12       8
# 52           RPC_BROWSER              196.00       2
# 53              FRSTRANS              301.52     606
# 54               DRSUAPI              163.00       2
# 55                   EPM              208.00       2
# 56                   POP              213.18      11
# 57               POP/IMF             1499.83      41
